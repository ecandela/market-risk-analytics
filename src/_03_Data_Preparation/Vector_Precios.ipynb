# %%
import pandas as pd

# %% [markdown]
# ## 1) Definición de parámetros generales
# - Archivo de fuentes de información
# - Fecha de procesamiento

# %%
db = 'TableroInformacion.xlsx'
fecha_proceso = "2023-06-15"

# %% [markdown]
# ## 2) Cargando datos
# - Se carga los datos de las fuentes y flujos de los bonos
# - Se elimina los espacios en blanco de las columnas

# %%
df_Bloomberg = pd.read_excel(db ,sheet_name='Bloomberg' , dtype = {'Fecha': str})
df_PIP = pd.read_excel(db ,sheet_name='PIP', dtype = {'Fecha': str})

df_SBS_PEN = pd.read_excel(db, sheet_name='SBS PEN', dtype = {'Fecha': str})
df_SBS_USD = pd.read_excel(db, sheet_name='SBS USD', dtype = {'Fecha': str})

df_Caracteristicas = pd.read_excel(db ,sheet_name='Caracteristicas')
df_Caracteristicas_variable = pd.read_excel(db ,sheet_name='Caracteristicas_variable')

df_flujos = pd.read_excel(db ,sheet_name='Flujo')

df_Bloomberg = df_Bloomberg.rename(columns=lambda x: x.strip())
df_PIP = df_PIP.rename(columns=lambda x: x.strip())
df_SBS_PEN = df_SBS_PEN.rename(columns=lambda x: x.strip())
df_SBS_USD = df_SBS_USD.rename(columns=lambda x: x.strip())
df_Caracteristicas = df_Caracteristicas.rename(columns=lambda x: x.strip())
df_flujos = df_flujos.rename(columns=lambda x: x.strip())

# %% [markdown]
# ## 3) Limpieza de datos
# - Eliminando espacios en blanco en la columna ISIN e Instrumento

# %%
df_Bloomberg['Instrumento'] = df_Bloomberg['Instrumento'].str.strip()
df_PIP['ISIN'] = df_PIP['ISIN'].str.strip()
df_SBS_PEN['ISIN'] = df_SBS_PEN['ISIN'].str.strip()
df_SBS_USD['ISIN'] = df_SBS_USD['ISIN'].str.strip()
df_Caracteristicas['ISIN'] = df_Caracteristicas['ISIN'].str.strip()
df_flujos['ISIN'] = df_flujos['ISIN'].str.strip()

# %% [markdown]
# - Formateando la columna Fecha

# %%
df_Bloomberg['Fecha'] = pd.to_datetime(df_Bloomberg['Fecha'], format='%Y-%m-%d')

df_PIP["Fecha"] = fecha_proceso
df_PIP['Fecha'] = pd.to_datetime(df_PIP['Fecha'], format='%Y-%m-%d')

df_SBS_PEN['Fecha'] = pd.to_datetime(df_SBS_PEN['Fecha'], format='%Y-%m-%d')
df_SBS_USD['Fecha'] = pd.to_datetime(df_SBS_USD['Fecha'], format='%Y-%m-%d')

# %% [markdown]
# - Homogeneizando valores de los precios

# %%
#igualando a la fecha de proceso y quitando lo de bloomberg que pertebece a la renta variable
df_Bloomberg_rent_fijo = df_Bloomberg[(df_Bloomberg.Fuente!="BLG") & (df_Bloomberg.Fecha==fecha_proceso) ].copy()

#igualando a la fecha de proceso y quitando lo de bloomberg que pertebece a la renta variable
df_Bloomberg_rent_variable = df_Bloomberg[(df_Bloomberg.Fuente=="BLG") & (df_Bloomberg.Fecha==fecha_proceso) ].copy()


df_Bloomberg_rent_fijo["Valor"] = df_Bloomberg_rent_fijo["Valor"]/100

df_PIP["Fuente"] = "PIP"

df_SBS_PEN["Fuente"] = "SBS"
df_SBS_PEN["P. Limpio (%)"] = df_SBS_PEN["P. Limpio (%)"]/100

df_SBS_USD["Fuente"] = "SBS"
df_SBS_USD["P. Limpio (%)"] = df_SBS_USD["P. Limpio (%)"]/100

# %% [markdown]
# ## 4) Renta Variable
# - Generación del archivo de vector de precios de renta variable

# %%
df_rent_variable = df_Bloomberg_rent_variable.copy()

#Ticker	Emisor	Moneda	Precio	Fuente

df_rent_variable.rename(columns={"Valor": "Precio","Instrumento": "Ticker"},inplace=True)

df_rent_variable = df_rent_variable[["Fecha",'Ticker',"Precio","Fuente"]].copy()

df_rent_variable = pd.merge(df_rent_variable,df_Caracteristicas_variable,right_on="Ticker",left_on="Ticker",how="inner")

df_rent_variable = df_rent_variable[["Ticker","Emisor","Moneda","Precio","Fuente"]].copy()
df_rent_variable
# Out:
#     Ticker                                             Emisor Moneda   Precio  \
# 0  5HED LN  Ossiam ESG Low Carbon Shiller Barclays Cape US...    USD   114.65
# 1   AAL LN                                 Anglo American PLC    GBp  2580.00
# 2   AAL US                        American Airlines Group Inc    USD    16.65
# 3  AAPL US                                          Apple Inc    USD   186.01
# 4   AAU CN                               Angold Resources Ltd    CAD     0.08
# 5  AAXJ US         iShares MSCI All Country Asia ex Japan ETF    USD    69.13
# 6  ABBV US                                         AbbVie Inc    USD   135.89
# 7  ABEV US                                           Ambev SA    USD     3.13
#
#   Fuente
# 0    BLG
# 1    BLG
# 2    BLG
# 3    BLG
# 4    BLG
# 5    BLG
# 6    BLG
# 7    BLG

# %% [markdown]
# ## 5) Renta Fija

# %% [markdown]
# - Generación del dataframe temporal "df_input_precio_bono_tmp" que centraliza los precios de las distintas fuentes. Este dataframe es la base para poder generar el dataframe "df_precio".

# %%
ipb_cls =  ['Fecha', 'ISIN', 'Precio','Fuente']

df_input_precio_bono_tmp = pd.DataFrame(columns = ipb_cls)

df_temp=pd.DataFrame(df_Bloomberg_rent_fijo[["Fecha","Instrumento","Valor","Fuente"]].values, columns=ipb_cls)
df_input_precio_bono_tmp = df_input_precio_bono_tmp.append(df_temp)

df_temp=pd.DataFrame(df_PIP[["Fecha","ISIN","Precio Limpio %","Fuente"]].values, columns=ipb_cls)
df_input_precio_bono_tmp = df_input_precio_bono_tmp.append(df_temp)

df_temp=pd.DataFrame(df_SBS_PEN[["Fecha","ISIN","P. Limpio (%)","Fuente"]].values, columns=ipb_cls)
df_input_precio_bono_tmp = df_input_precio_bono_tmp.append(df_temp)

df_temp=pd.DataFrame(df_SBS_USD[["Fecha","ISIN","P. Limpio (%)","Fuente"]].values, columns=ipb_cls)
df_input_precio_bono_tmp = df_input_precio_bono_tmp.append(df_temp)

df_input_precio_bono_tmp.head()
# Out:
#        Fecha          ISIN    Precio Fuente
# 0 2023-06-15  US912810EQ77  1.000664   TRAC
# 1 2023-06-15  US912810EQ77  1.000664   BVAL
# 2 2023-06-15  US912810EQ77  0.998906    BGN
# 3 2023-06-15  US912810FJ26  1.119219    BGN
# 4 2023-06-15  US912810FJ26  1.119297   BVAL

# %% [markdown]
# - Desarrollo de funciones utilitarias para el vector de precios de renta fija
#     - set_metodo_nuevo: Calculo de la variable "MetodoValNuevo" que define el método de cálculo que se empleara para el precio del activo
#     - set_precio_nuevo: Determina el "PrecioLimpio" correspondiente a la variable "MetodoValNuevo"
#     - calculo_TIR: Cálculo del TIR
#     - get_TIR_anterior: Calculo del TIR anterior

# %%
def set_metodo_nuevo(fila):

    if fila['ISIN'][:3]=="PEP" :

        if fila['Tipo Bono']=="Certificado Deposito":  
        # Aplicar la lógica del switch case
            if pd.isna(fila['PIP'])==False:
                return 'PIP'
            else:
                return 'TIR'
        
        else:

            if pd.isna(fila['PIP'])==False:
                return 'PIP'
            elif pd.isna(fila['SBS'])==False:
                return 'SBS'
            else:
                return 'TIR'          
        
    else:

        if pd.isna(fila['BVAL'])==False:
            return 'BVAL'
        if pd.isna(fila['BGN'])==False:
            return 'BGN'
        if pd.isna(fila['TRAC'])==False:
            return 'TRAC'
        else:
            return 'TIR'
        

def set_precio_nuevo(fila):

    MetodoValNuevo = fila['MetodoValNuevo']

    return fila[MetodoValNuevo]

def calculo_TIR(fila):

    tir = ((fila['Amortización'])/((1+fila['Tasa Bono'])**(fila['Plazo']/365)))

    return tir


def get_TIR_anterior(fecha_proceso_param,df_flujos_,isin):

    fecha_proceso_dt = pd.to_datetime(fecha_proceso_param)

    df_flujos_bono = df_flujos_[(df_flujos_.ISIN==isin) & (df_flujos_["Fecha Vto"]<fecha_proceso_dt)].copy()

    df_flujos_bono.sort_values(by="Fecha Vto",ascending=True,inplace=True)

    df_flujos_bono["Plazo"] =  (df_flujos_bono["Fecha Vto"] - fecha_proceso_dt).dt.days

   
    df_flujos_bono['TIR'] = df_flujos_bono.apply(calculo_TIR, axis=1)

    df_flujos_bono_agg = df_flujos_bono.groupby(["ISIN"],as_index=False).agg({'TIR': "sum"})
    df_flujos_bono_agg["TIR"] = df_flujos_bono_agg["TIR"]/100


    TIR = df_flujos_bono_agg.loc[0, 'TIR'] 

    return TIR

# %% [markdown]
# - Generación del dataframe utilitario "df_precio" que lista los precios de los activos de renta fija

# %%
cls_carac = ["ISIN","Pais Emisor","Tipo Bono"]
df_precio = df_Caracteristicas[cls_carac].copy()
print(df_precio.shape)
for fuente in ["PIP","BVAL","BGN","TRAC","SBS","TIR"]:
    df_ipb_temp= df_input_precio_bono_tmp[(df_input_precio_bono_tmp.Fecha==fecha_proceso) & (df_input_precio_bono_tmp.Fuente==fuente)][["ISIN","Precio"]].copy()
    df_ipb_temp.rename(columns={"Precio": fuente},  inplace=True )
    df_precio = pd.merge(df_precio,df_ipb_temp,left_on="ISIN",right_on="ISIN",how="left")

    if fuente == "TIR":
        df_precio['TIR'] = None
        for index, row in df_precio.iterrows():
            # Obtén el valor actual de 'columna_actualizar'
            isin = row['ISIN']
            try:
                tir = get_TIR_anterior(fecha_proceso,df_flujos,isin)
                # Actualiza el valor en la columna correspondiente     
                df_precio.at[index, 'TIR'] = tir
            except:
                continue

df_precio['MetodoValNuevo'] = df_precio.apply(set_metodo_nuevo, axis=1)
df_precio['PrecioLimpio'] = df_precio.apply(set_precio_nuevo, axis=1)

df_precio
# Out:
# (31, 3)
#             ISIN Pais Emisor             Tipo Bono       PIP      BVAL  \
# 0   PEP12100D243          PE      Bono Corporativo       NaN       NaN
# 1   PEP58501M073          PE         Bono Soberano  0.991568       NaN
# 2   PEP72760M010          PE      Bono Corporativo   0.91496       NaN
# 3   PEP73125M049          US      Bono Corporativo  0.987375       NaN
# 4   PEP73125M056          US      Bono Corporativo  0.964907       NaN
# 5   PEP73125M064          PE         Bono Soberano  0.901541       NaN
# 6   US912810EQ77          US           Bono Tesoro       NaN  1.000664
# 7   US912810FJ26          US           Bono Tesoro       NaN  1.119297
# 8   US912810FT08          US           Bono Tesoro       NaN  1.085625
# 9   US912810PU60          US           Bono Tesoro       NaN   1.13875
# 10  US912810PW27          US           Bono Tesoro       NaN      1.07
# 11  US912810PX00          US           Bono Tesoro       NaN    1.0825
# 12  US912810QC53          US           Bono Tesoro       NaN  1.082031
# 13  US912810QL52          US           Bono Tesoro       NaN     1.045
# 14  US912810QN19          US           Bono Tesoro       NaN  1.109531
# 15  US912810QQ40          US           Bono Tesoro       NaN  1.057656
# 16  US912810QS06          US           Bono Tesoro       NaN  0.971875
# 17  US912810QT88          US           Bono Tesoro       NaN  0.885469
# 18  US912810QU51          US           Bono Tesoro       NaN  0.882656
# 19  US912810QW18          US           Bono Tesoro       NaN  0.863594
# 20  US912810QX90          US           Bono Tesoro       NaN  0.827812
# 21  US912810QY73          US           Bono Tesoro       NaN  0.826406
# 22  US912810QZ49          US           Bono Tesoro       NaN  0.876563
# 23  US912810RB61          US           Bono Tesoro       NaN      0.84
# 24  US912810RC45          US           Bono Tesoro       NaN  0.944688
# 25  US912810RD28          US           Bono Tesoro       NaN  0.961719
# 26  US912810RE01          US           Bono Tesoro       NaN  0.942344
# 27  US912810RG58          US           Bono Tesoro       NaN  0.905937
# 28  US912810RH32          US           Bono Tesoro       NaN  0.869062
# 29   C00A1031023          PE  Certificado Deposito       NaN       NaN
# 30   C00A1080923          PE  Certificado Deposito       NaN       NaN
#
#          BGN      TRAC      SBS   TIR MetodoValNuevo  PrecioLimpio
# 0        NaN       NaN  1.01315  None            SBS      1.013150
# 1        NaN       NaN  0.96688  None            PIP      0.991568
# 2        NaN       NaN      NaN  None            PIP      0.914960
# 3        NaN       NaN      NaN  None            PIP      0.987375
# 4        NaN       NaN      NaN  None            PIP      0.964907
# 5        NaN       NaN      NaN  None            PIP      0.901541
# 6   0.998906  1.000664      NaN   0.0           BVAL      1.000664
# 7   1.119219  1.119297      NaN  None           BVAL      1.119297
# 8   1.084844  1.085625      NaN   0.0           BVAL      1.085625
# 9   1.137969   1.13875      NaN   0.0           BVAL      1.138750
# 10  1.069063      1.07      NaN   0.0           BVAL      1.070000
# 11  1.081719    1.0825      NaN   0.0           BVAL      1.082500
# 12   1.08125  1.082031      NaN   0.0           BVAL      1.082031
# 13  1.044531     1.045      NaN   0.0           BVAL      1.045000
# 14  1.109063  1.109531      NaN   0.0           BVAL      1.109531
# 15  1.057344  1.057656      NaN   0.0           BVAL      1.057656
# 16  0.971719  0.971875      NaN   0.0           BVAL      0.971875
# 17  0.885312  0.885469      NaN   0.0           BVAL      0.885469
# 18    0.8825  0.882656      NaN   0.0           BVAL      0.882656
# 19  0.863437  0.863594      NaN   0.0           BVAL      0.863594
# 20  0.827656  0.827812      NaN   0.0           BVAL      0.827812
# 21   0.82625  0.826406      NaN   0.0           BVAL      0.826406
# 22  0.876406  0.876563      NaN   0.0           BVAL      0.876563
# 23      0.84      0.84      NaN   0.0           BVAL      0.840000
# 24  0.944688  0.944688      NaN   0.0           BVAL      0.944688
# 25  0.961562  0.961719      NaN   0.0           BVAL      0.961719
# 26  0.942344  0.942344      NaN   0.0           BVAL      0.942344
# 27  0.905781  0.905937      NaN   0.0           BVAL      0.905937
# 28   0.86875  0.869062      NaN   0.0           BVAL      0.869062
# 29       NaN       NaN      NaN  None            TIR           NaN
# 30       NaN       NaN      NaN  None            TIR           NaN

# %% [markdown]
# - Desarrollo de funciones utilitarias para el desarrollo de "df_renta_fija"
#     - calculo_duracion: Permite calcular la duración
#     - get_plazo_corrido: permite poner el plazo corrido
#     - get_duracion_and_TIR: Calcula la duración y TIR

# %%
def calculo_duracion(fila):
    try:
        duracion = ((fila['Amortización']*fila['Plazo']/365)/((1+fila['Tasa Bono'])**(fila['Plazo']/365)))/(fila['Amortización']/(1+fila['Tasa Bono'])**(fila['Plazo']/365))
    except:
        duracion = 0

    return duracion



def get_plazo_corrido(fecha_proceso,base_calculo, df_flujos_,isin):

    fecha_proceso_dt = pd.to_datetime(fecha_proceso)

    df_flujos_bono = df_flujos_[(df_flujos_.ISIN==isin) & (df_flujos_["Fecha Vto"]<fecha_proceso_dt)].copy()

    if len(df_flujos_bono)==0:
        return None

    df_flujos_bono.sort_values(by="Fecha Vto",ascending=True,inplace=True)

    FecVtoAnteriorCupo = df_flujos_bono['Fecha Vto'].iloc[-1]

    if base_calculo=="ACT/ACT":

        plazoCorrido =  (fecha_proceso_dt - FecVtoAnteriorCupo).days

    else:

        D1 = FecVtoAnteriorCupo.day
        M1 = FecVtoAnteriorCupo.month
        Y1 = FecVtoAnteriorCupo.year

        D2 = fecha_proceso_dt.day
        M2 = fecha_proceso_dt.month
        Y2 = fecha_proceso_dt.year

        if base_calculo=="030/360":
            DIAS_YEAR = 360
            DIAS_MONTH = 30
        if base_calculo=="030/365":
            DIAS_YEAR = 365
            DIAS_MONTH = 30
        if base_calculo=="ACT/360":
            DIAS_YEAR = 360
            DIAS_MONTH = fecha_proceso_dt.days_in_month


        plazoCorrido = (Y2-Y1)*DIAS_YEAR + (M2-M1)*DIAS_MONTH + (D2-D1)    

    return plazoCorrido

def get_duracion_and_TIR(fecha_proceso_param,df_flujos_param,isin):

    fecha_proceso_dt = pd.to_datetime(fecha_proceso_param)

    df_flujos_bono = df_flujos_param[(df_flujos_param.ISIN==isin) & (df_flujos_param["Fecha Vto"]>=fecha_proceso_dt)].copy()

    if len(df_flujos_bono)==0:
        return None , None

    df_flujos_bono.sort_values(by="Fecha Vto",ascending=True,inplace=True)

    df_flujos_bono["Plazo"] =  (df_flujos_bono["Fecha Vto"] - fecha_proceso_dt).dt.days

    df_flujos_bono['Duracion'] = df_flujos_bono.apply(calculo_duracion, axis=1)
    df_flujos_bono['TIR'] = df_flujos_bono.apply(calculo_TIR, axis=1)

    df_flujos_bono_agg = df_flujos_bono.groupby(["ISIN"],as_index=False).agg({'Duracion': "sum", 'TIR': "sum"})
    df_flujos_bono_agg["TIR"] = df_flujos_bono_agg["TIR"]/100

    Duracion = df_flujos_bono_agg.loc[0, 'Duracion']  # Valor en la primera fila, columna1
    TIR = df_flujos_bono_agg.loc[0, 'TIR'] 

    return Duracion , TIR

# %% [markdown]
# Generación del dataframe "df_renta_fija"

# %%
df_renta_fija = df_Caracteristicas.copy()

#Fecha	ISIN	Emisor	Moneda	Tasa Cupon	Fec. Vcto	TIR Mcdo	Precio Limpio (%)	Int. Corrido (%)	Reajuste VAC	Precio Mcdo (%)	Dur. Normal	Fuente

for index, row in df_renta_fija.iterrows():
    #try:
    # Obtén el valor actual de 'columna_actualizar'
    isin = row['ISIN']
    base_calculo = row['Base Calculo Interes Corrido']
    #print(f"-{isin}-")
    dur, tir = get_duracion_and_TIR(fecha_proceso,df_flujos,isin)
    plazoCorrido = get_plazo_corrido(fecha_proceso,base_calculo,df_flujos,isin)
    # Actualiza el valor en la columna correspondiente
    df_renta_fija.at[index, 'PlazoCorrido'] = plazoCorrido


    df_renta_fija.at[index, 'Duracion'] = dur
    df_renta_fija.at[index, 'TIR'] = tir
    #except:
    #    continue

df_renta_fija["InteresCorrido"] = df_renta_fija["Tasa cupon"]*1*df_renta_fija["PlazoCorrido"] / 365

df_renta_fija = pd.merge(df_renta_fija,df_precio[["ISIN","MetodoValNuevo","PrecioLimpio"]],right_on="ISIN",left_on="ISIN",how="left")

df_renta_fija["PrecioSucio"] = df_renta_fija["InteresCorrido"]  + df_renta_fija["InteresCorrido"]

df_renta_fija["Reajuste VAC"]  = None
df_renta_fija["Precio Mcdo (%)"]  = None

df_renta_fija
# Out:
#             ISIN Fecha Inicio  Fecha Vto  Tasa cupon Frecuencia Pago  \
# 0   PEP12100D243   2016-04-06 2024-04-06    0.000000               S
# 1   PEP58501M073   2018-11-14 2033-11-14    0.068400               S
# 2   PEP72760M010   2022-02-25 2037-02-25    0.072813               S
# 3   PEP73125M049   2018-07-23 2028-07-23    0.070625               S
# 4   PEP73125M056   2018-07-23 2038-07-23    0.076875               S
# 5   PEP73125M064   2019-11-15 2031-11-15    0.059687               S
# 6   US912810EQ77   1993-08-16 2023-08-16    0.062500               S
# 7   US912810FJ26   1999-08-16 2029-08-15    0.061250               S
# 8   US912810FT08   2006-02-15 2036-02-15    0.045000               S
# 9   US912810PU60   2007-08-15 2037-05-15    0.050000               S
# 10  US912810PW27   2008-02-15 2038-02-15    0.043750               S
# 11  US912810PX00   2008-08-15 2038-05-15    0.045000               S
# 12  US912810QC53   2009-08-17 2039-08-15    0.045000               S
# 13  US912810QL52   2010-11-15 2040-11-15    0.042500               S
# 14  US912810QN19   2011-02-15 2041-02-15    0.047500               S
# 15  US912810QQ40   2011-05-16 2041-05-15    0.043750               S
# 16  US912810QS06   2011-08-15 2041-08-15    0.037500               S
# 17  US912810QT88   2011-11-15 2041-11-15    0.031250               S
# 18  US912810QU51   2012-02-15 2042-02-15    0.031250               S
# 19  US912810QW18   2012-05-15 2042-05-15    0.030000               S
# 20  US912810QX90   2012-08-15 2042-08-15    0.027500               S
# 21  US912810QY73   2012-11-15 2042-11-15    0.027500               S
# 22  US912810QZ49   2013-02-15 2043-02-15    0.031250               S
# 23  US912810RB61   2013-05-15 2043-05-15    0.028750               S
# 24  US912810RC45   2013-08-15 2043-08-15    0.036250               S
# 25  US912810RD28   2013-11-15 2043-11-15    0.037500               S
# 26  US912810RE01   2014-02-15 2044-02-15    0.036250               S
# 27  US912810RG58   2014-05-15 2044-05-15    0.033750               S
# 28  US912810RH32   2014-08-15 2044-08-15    0.031250               S
# 29   C00A1031023   2023-10-03 2023-03-31    0.000000              PV
# 30   C00A1080923   2023-09-08 2023-03-10    0.000000              PV
#
#    Base Calculo Interes Corrido Tipo Tasa  \
# 0                       ACT/ACT  Variable
# 1                       ACT/ACT      Fijo
# 2                       030/360      Fijo
# 3                       030/360      Fijo
# 4                       030/360      Fijo
# 5                       ACT/360      Fijo
# 6                       ACT/ACT      Fijo
# 7                       ACT/ACT      Fijo
# 8                       ACT/ACT      Fijo
# 9                       ACT/ACT      Fijo
# 10                      ACT/ACT      Fijo
# 11                      ACT/ACT      Fijo
# 12                      ACT/ACT      Fijo
# 13                      ACT/ACT      Fijo
# 14                      ACT/ACT      Fijo
# 15                      ACT/360      Fijo
# 16                      ACT/ACT      Fijo
# 17                      ACT/ACT      Fijo
# 18                      ACT/ACT      Fijo
# 19                      ACT/ACT      Fijo
# 20                      ACT/ACT      Fijo
# 21                      ACT/ACT      Fijo
# 22                      ACT/ACT      Fijo
# 23                      ACT/ACT      Fijo
# 24                      ACT/ACT      Fijo
# 25                      ACT/ACT      Fijo
# 26                      ACT/ACT      Fijo
# 27                      ACT/ACT      Fijo
# 28                      ACT/ACT      Fijo
# 29                      ACT/360      Fijo
# 30                      ACT/360      Fijo
#
#                                   Emisor Pais Emisor Moneda  \
# 0       BANCO INTERAMERICANO DE FINANZAS          PE    USD
# 1                      GOBIERNO DEL PERU          PE    PEN
# 2   CENTENARIO RENTA INMOBILIARIA S.A.C.          PE    USD
# 3                  CORPORACIÓN PRIMAX SA          US    PEN
# 4                  CORPORACIÓN PRIMAX SA          US    PEN
# 5                      GOBIERNO DEL PERU          PE    PEN
# 6                        US TREASURY N/B          US    USD
# 7                            US TREASURY          US    USD
# 8                        US TREASURY N/B          US    USD
# 9                            US TREASURY          US    USD
# 10                       US TREASURY N/B          US    USD
# 11                       US TREASURY N/B          US    USD
# 12                       US TREASURY N/B          US    USD
# 13                       US TREASURY N/B          US    USD
# 14                       US TREASURY N/B          US    USD
# 15                       US TREASURY N/B          US    USD
# 16                           US TREASURY          US    USD
# 17                           US TREASURY          US    USD
# 18                           US TREASURY          US    USD
# 19                           US TREASURY          US    USD
# 20                           US TREASURY          US    USD
# 21                           US TREASURY          US    USD
# 22                           US TREASURY          US    USD
# 23                           US TREASURY          US    USD
# 24                       US TREASURY N/B          US    USD
# 25                       US TREASURY N/B          US    USD
# 26                       US TREASURY N/B          US    USD
# 27                           US TREASURY          US    USD
# 28                       US TREASURY N/B          US    USD
# 29     BANCO CENTRAL DE RESERVA DEL PERU          PE    PEN
# 30     BANCO CENTRAL DE RESERVA DEL PERU          PE    USD
#
#                Tipo Bono  PlazoCorrido   Duracion       TIR  InteresCorrido  \
# 0       Bono Corporativo           NaN        NaN       NaN             NaN
# 1          Bono Soberano           NaN        NaN       NaN             NaN
# 2       Bono Corporativo           NaN        NaN       NaN             NaN
# 3       Bono Corporativo           NaN        NaN       NaN             NaN
# 4       Bono Corporativo           NaN        NaN       NaN             NaN
# 5          Bono Soberano           NaN        NaN       NaN             NaN
# 6            Bono Tesoro         119.0   0.169863  0.989755        0.020377
# 7            Bono Tesoro           NaN        NaN       NaN             NaN
# 8            Bono Tesoro         120.0  12.679452  0.572290        0.014795
# 9            Bono Tesoro          31.0  13.926027  0.506894        0.004247
# 10           Bono Tesoro         120.0  14.682192  0.533289        0.014384
# 11           Bono Tesoro          31.0  14.926027  0.518406        0.003822
# 12           Bono Tesoro         120.0  16.178082  0.490609        0.014795
# 13           Bono Tesoro          31.0  17.432877  0.484041        0.003610
# 14           Bono Tesoro         120.0  17.684932  0.440126        0.015616
# 15           Bono Tesoro          30.0  17.928767  0.464075        0.003596
# 16           Bono Tesoro         120.0  18.180822  0.512063        0.012329
# 17           Bono Tesoro          31.0  18.432877  0.567105        0.002654
# 18           Bono Tesoro         120.0  18.684932  0.562724        0.010274
# 19           Bono Tesoro          31.0  18.928767  0.571488        0.002548
# 20           Bono Tesoro         120.0  19.180822  0.594312        0.009041
# 21           Bono Tesoro          31.0  19.432877  0.590262        0.002336
# 22           Bono Tesoro         120.0  19.684932  0.545672        0.010274
# 23           Bono Tesoro          31.0  19.928767  0.568434        0.002442
# 24           Bono Tesoro         120.0  20.180822  0.487431        0.011918
# 25           Bono Tesoro          31.0  20.432877  0.471321        0.003185
# 26           Bono Tesoro         120.0  20.684932  0.478759        0.011918
# 27           Bono Tesoro          31.0  20.931507  0.499185        0.002866
# 28           Bono Tesoro         120.0  21.183562  0.521079        0.010274
# 29  Certificado Deposito           NaN        NaN       NaN             NaN
# 30  Certificado Deposito           NaN        NaN       NaN             NaN
#
#    MetodoValNuevo  PrecioLimpio  PrecioSucio Reajuste VAC Precio Mcdo (%)
# 0             SBS      1.013150          NaN         None            None
# 1             PIP      0.991568          NaN         None            None
# 2             PIP      0.914960          NaN         None            None
# 3             PIP      0.987375          NaN         None            None
# 4             PIP      0.964907          NaN         None            None
# 5             PIP      0.901541          NaN         None            None
# 6            BVAL      1.000664     0.040753         None            None
# 7            BVAL      1.119297          NaN         None            None
# 8            BVAL      1.085625     0.029589         None            None
# 9            BVAL      1.138750     0.008493         None            None
# 10           BVAL      1.070000     0.028767         None            None
# 11           BVAL      1.082500     0.007644         None            None
# 12           BVAL      1.082031     0.029589         None            None
# 13           BVAL      1.045000     0.007219         None            None
# 14           BVAL      1.109531     0.031233         None            None
# 15           BVAL      1.057656     0.007192         None            None
# 16           BVAL      0.971875     0.024658         None            None
# 17           BVAL      0.885469     0.005308         None            None
# 18           BVAL      0.882656     0.020548         None            None
# 19           BVAL      0.863594     0.005096         None            None
# 20           BVAL      0.827812     0.018082         None            None
# 21           BVAL      0.826406     0.004671         None            None
# 22           BVAL      0.876563     0.020548         None            None
# 23           BVAL      0.840000     0.004884         None            None
# 24           BVAL      0.944688     0.023836         None            None
# 25           BVAL      0.961719     0.006370         None            None
# 26           BVAL      0.942344     0.023836         None            None
# 27           BVAL      0.905937     0.005733         None            None
# 28           BVAL      0.869062     0.020548         None            None
# 29            TIR           NaN          NaN         None            None
# 30            TIR           NaN          NaN         None            None

# %% [markdown]
# ## 6) Controles de validación

# %% [markdown]
# TIR: La rentabilidad del instrumento deberá ser positiva

# %%
#df_renta_fija = df_renta_fija[(df_renta_fija["TIR"] >= 0)].copy()

# %% [markdown]
# Solo deben considerarse instrumentos de renta fija presente fecha de próximo
# cupón o vencimiento.

# %%
fecha_proceso_dt = pd.to_datetime(fecha_proceso)
df_renta_fija = df_renta_fija[(df_renta_fija["Fecha Vto"] >= fecha_proceso_dt)].copy()
#df_renta_fija

# %% [markdown]
# ## 7) Exportación

# %% [markdown]
# - Formateando el dataframe con las variables solicitadas

# %%
cls_ori = ["Fecha Vto","ISIN","Emisor","Moneda","Tasa cupon","Fecha Vto","TIR","PrecioLimpio","InteresCorrido","Reajuste VAC","PrecioLimpio","Duracion","MetodoValNuevo"] 
cls_des = ["Fecha","ISIN",	"Emisor","Moneda","Tasa Cupon","Fec. Vcto","TIR Mcdo","Precio Limpio (%)","Int. Corrido (%)","Reajuste VAC","Precio Mcdo (%)","Dur. Normal","Fuente"] 

df_renta_fija=pd.DataFrame(df_renta_fija[cls_ori].values, columns=cls_des)

# %%
df_renta_fija
# Out:
#         Fecha          ISIN                                Emisor Moneda  \
# 0  2024-04-06  PEP12100D243      BANCO INTERAMERICANO DE FINANZAS    USD
# 1  2033-11-14  PEP58501M073                     GOBIERNO DEL PERU    PEN
# 2  2037-02-25  PEP72760M010  CENTENARIO RENTA INMOBILIARIA S.A.C.    USD
# 3  2028-07-23  PEP73125M049                 CORPORACIÓN PRIMAX SA    PEN
# 4  2038-07-23  PEP73125M056                 CORPORACIÓN PRIMAX SA    PEN
# 5  2031-11-15  PEP73125M064                     GOBIERNO DEL PERU    PEN
# 6  2023-08-16  US912810EQ77                       US TREASURY N/B    USD
# 7  2029-08-15  US912810FJ26                           US TREASURY    USD
# 8  2036-02-15  US912810FT08                       US TREASURY N/B    USD
# 9  2037-05-15  US912810PU60                           US TREASURY    USD
# 10 2038-02-15  US912810PW27                       US TREASURY N/B    USD
# 11 2038-05-15  US912810PX00                       US TREASURY N/B    USD
# 12 2039-08-15  US912810QC53                       US TREASURY N/B    USD
# 13 2040-11-15  US912810QL52                       US TREASURY N/B    USD
# 14 2041-02-15  US912810QN19                       US TREASURY N/B    USD
# 15 2041-05-15  US912810QQ40                       US TREASURY N/B    USD
# 16 2041-08-15  US912810QS06                           US TREASURY    USD
# 17 2041-11-15  US912810QT88                           US TREASURY    USD
# 18 2042-02-15  US912810QU51                           US TREASURY    USD
# 19 2042-05-15  US912810QW18                           US TREASURY    USD
# 20 2042-08-15  US912810QX90                           US TREASURY    USD
# 21 2042-11-15  US912810QY73                           US TREASURY    USD
# 22 2043-02-15  US912810QZ49                           US TREASURY    USD
# 23 2043-05-15  US912810RB61                           US TREASURY    USD
# 24 2043-08-15  US912810RC45                       US TREASURY N/B    USD
# 25 2043-11-15  US912810RD28                       US TREASURY N/B    USD
# 26 2044-02-15  US912810RE01                       US TREASURY N/B    USD
# 27 2044-05-15  US912810RG58                           US TREASURY    USD
# 28 2044-08-15  US912810RH32                       US TREASURY N/B    USD
#
#    Tasa Cupon  Fec. Vcto  TIR Mcdo Precio Limpio (%) Int. Corrido (%)  \
# 0         0.0 2024-04-06       NaN           1.01315              NaN
# 1      0.0684 2033-11-14       NaN          0.991568              NaN
# 2    0.072813 2037-02-25       NaN           0.91496              NaN
# 3    0.070625 2028-07-23       NaN          0.987375              NaN
# 4    0.076875 2038-07-23       NaN          0.964907              NaN
# 5    0.059687 2031-11-15       NaN          0.901541              NaN
# 6      0.0625 2023-08-16  0.989755          1.000664         0.020377
# 7     0.06125 2029-08-15       NaN          1.119297              NaN
# 8       0.045 2036-02-15   0.57229          1.085625         0.014795
# 9        0.05 2037-05-15  0.506894           1.13875         0.004247
# 10    0.04375 2038-02-15  0.533289              1.07         0.014384
# 11      0.045 2038-05-15  0.518406            1.0825         0.003822
# 12      0.045 2039-08-15  0.490609          1.082031         0.014795
# 13     0.0425 2040-11-15  0.484041             1.045          0.00361
# 14     0.0475 2041-02-15  0.440126          1.109531         0.015616
# 15    0.04375 2041-05-15  0.464075          1.057656         0.003596
# 16     0.0375 2041-08-15  0.512063          0.971875         0.012329
# 17    0.03125 2041-11-15  0.567105          0.885469         0.002654
# 18    0.03125 2042-02-15  0.562724          0.882656         0.010274
# 19       0.03 2042-05-15  0.571488          0.863594         0.002548
# 20     0.0275 2042-08-15  0.594312          0.827812         0.009041
# 21     0.0275 2042-11-15  0.590262          0.826406         0.002336
# 22    0.03125 2043-02-15  0.545672          0.876563         0.010274
# 23    0.02875 2043-05-15  0.568434              0.84         0.002442
# 24    0.03625 2043-08-15  0.487431          0.944688         0.011918
# 25     0.0375 2043-11-15  0.471321          0.961719         0.003185
# 26    0.03625 2044-02-15  0.478759          0.942344         0.011918
# 27    0.03375 2044-05-15  0.499185          0.905937         0.002866
# 28    0.03125 2044-08-15  0.521079          0.869062         0.010274
#
#    Reajuste VAC Precio Mcdo (%) Dur. Normal Fuente
# 0          None         1.01315         NaN    SBS
# 1          None        0.991568         NaN    PIP
# 2          None         0.91496         NaN    PIP
# 3          None        0.987375         NaN    PIP
# 4          None        0.964907         NaN    PIP
# 5          None        0.901541         NaN    PIP
# 6          None        1.000664    0.169863   BVAL
# 7          None        1.119297         NaN   BVAL
# 8          None        1.085625   12.679452   BVAL
# 9          None         1.13875   13.926027   BVAL
# 10         None            1.07   14.682192   BVAL
# 11         None          1.0825   14.926027   BVAL
# 12         None        1.082031   16.178082   BVAL
# 13         None           1.045   17.432877   BVAL
# 14         None        1.109531   17.684932   BVAL
# 15         None        1.057656   17.928767   BVAL
# 16         None        0.971875   18.180822   BVAL
# 17         None        0.885469   18.432877   BVAL
# 18         None        0.882656   18.684932   BVAL
# 19         None        0.863594   18.928767   BVAL
# 20         None        0.827812   19.180822   BVAL
# 21         None        0.826406   19.432877   BVAL
# 22         None        0.876563   19.684932   BVAL
# 23         None            0.84   19.928767   BVAL
# 24         None        0.944688   20.180822   BVAL
# 25         None        0.961719   20.432877   BVAL
# 26         None        0.942344   20.684932   BVAL
# 27         None        0.905937   20.931507   BVAL
# 28         None        0.869062   21.183562   BVAL

# %% [markdown]
# - Formateando el dataframe con las variables solicitadas

# %%
with pd.ExcelWriter('EstructuraVectorFinal.xlsx') as writer:      
    df_renta_fija.to_excel(writer, sheet_name='RentaFija')
    df_rent_variable.to_excel(writer, sheet_name='RentaVariable')
